# %% [markdown]
# ## Visualisation in Python - Matplotlib

# %% [markdown]
# ### Line Chart: Trend of sales over the 12 months

# %% [markdown]
# -  Can be used to present the trend with time variable on the x-axis
# -  In some cases, can be used as an alternative to scatterplot to understand the relationship between 2 variables

# %%
# importing the required libraries
import numpy as np
import matplotlib.pyplot as plt

# Sales data across months
months = np.array(['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'])
sales = np.array([241268.56, 184837.36, 263100.77, 242771.86, 288401.05, 401814.06, 258705.68, 456619.94, 481157.24, 422766.63, 555279.03, 503143.69])

# %%
# plotting a line chart
import numpy as np
import matplotlib.pyplot as plt
months = np.array(['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'])
sales = np.array([241268.56, 184837.36, 263100.77, 242771.86, 288401.05, 401814.06, 258705.68, 456619.94, 481157.24, 422766.63, 555279.03, 503143.69])
plt.plot(months,sales,fontdict={"fontsize":20,"fontwidth":6,"color":"green"})
plt.title("Sales Data across the month.",color="Cyan")
plt.xlabel("Month",color="Red")
plt.ylabel("Sales",color="Orange")
plt.xticks(rotation=90)



# adding title to the chart


# labeling the axes


# rotating the tick values of x-axis


# displating the created plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [36], in <cell line: 6>()
#       4 months = np.array(['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'])
#       5 sales = np.array([241268.56, 184837.36, 263100.77, 242771.86, 288401.05, 401814.06, 258705.68, 456619.94, 481157.24, 422766.63, 555279.03, 503143.69])
# ----> 6 plt.plot(months,sales,fontdict={"fontsize":20,"fontwidth":6,"color":"green"})
#       7 plt.title("Sales Data across the month.",color="Cyan")
#       8 plt.xlabel("Month",color="Red")
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:2757, in plot(scalex, scaley, data, *args, **kwargs)
#    2755 @_copy_docstring_and_deprecators(Axes.plot)
#    2756 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2757     return gca().plot(
# ...

# %%
y = np.random.randint(1,100, 50)
plt.plot(y, 'ro') #You should be careful when using the function plt.plot. The same function generates a scatterplot if you tweak the syntax and specify the markers. Try to run the code below to understand the difference:

  # ‘ro’ represents color (r) and marker (o)

# %% [markdown]
# ### A line graph is very helpful when you want to understand the trend of a variable. Some key industries and services that rely on line graphs are financial markets, weather forecast, etc.  In the video above, you also learnt how to rotate the tick labels on the axes:

# %%
plt.plot(y, 'red', marker = 'o')# it will give line graph

# %%
# if we use marker = "x for above"

# %%
plt.plot(y, 'orange', marker = 'x')
plt.title(" 50 Randon no between 1 to 100",color="green")
plt.xlabel("X axis", color="red")
plt.ylabel("Y axis",color="Cyan")
plt.show()

# %% [markdown]
# # Histogram

# %%
list_1 = [48.49, 67.54, 57.47, 68.17, 51.18, 68.31, 50.33, 66.7, 45.62, 43.59, 53.64, 70.08, 47.69, 61.27, 44.14, 51.62, 48.72, 65.11]

# %%
weight=np.array(list_1)

# %%
plt.hist(weight, bins = 4, range =[40, 80], edgecolor = 'white')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

list_1 = [48.49, 67.54, 57.47, 68.17, 51.18, 68.31, 50.33, 66.7, 45.62, 43.59, 53.64, 70.08, 47.69, 61.27, 44.14, 51.62, 48.72, 65.11]

print("Interperecentil range : ", np.percentile(list_1, 25),"-", np.percentile(list_1, 75))
# Out:
# Interperecentil range :  48.5475 - 66.30250000000001
